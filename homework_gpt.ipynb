# %% [markdown]
# # Домашнее задание № 10. Генерация текста

# %% [markdown]
# ### Задание 1 (8 баллов).
#
# Попробуйте дообучать GPT на каком-то другом тексте (можете попробовать любые стихи или какие-то специфичные вещи вроде анекдотов или репа).
# Попробуйте разные методы и параметры генерации (beam search, температура, top_k и тп). Сохраните в тетрадке несколько хороших сгенерированных текстов

# %%
# %pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from transformers.utils import logging
logging.set_verbosity(40)

from transformers import TextDataset, DataCollatorForLanguageModeling, Trainer, TrainingArguments


from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch
DEVICE = torch.device("cuda:0")

# %%
model_name_or_path = "sberbank-ai/rugpt3small_based_on_gpt2"
tokenizer = GPT2Tokenizer.from_pretrained(model_name_or_path)
model = GPT2LMHeadModel.from_pretrained(model_name_or_path, use_cache=False).to(DEVICE)

# %%
#Анекдоты про Штирлица...

text = """
	Мюллер вызывает Штирлица и говорит:
- Завтра коммунистический субботник, явка обязательна.
Штирлиц отвечает:
- Есть!
- И, поняв, что провалился, садится за стол и, не замечая удивлённого взгляда Мюллера, пишет:
- Я, штандартенфюрер фон Штирлиц, на самом деле являюсь советским разведчиком.
Мюллер, прочитав этот рапорт, звонит Шелленбергу и говорит.
- Вальтер, зайдите, посмотрите, что ваши люди придумывают, чтобы на субботник не ходить.

Штирлиц играл в карты и проигрался. Но Штирлиц умел делать хорошую мину при плохой игре. Когда Штирлиц покинул компанию, мина сработала.

Штирлиц и Мюллер ездили по очереди на танке. Очередь редела, но не расходилась...

Штирлиц стрелял вслепую. Слепая испугалась и побежала скачками, но качки быстро отстали.

Подвыпившие Штирлиц и Мюллер вышли из бара.
- Давайте снимем девочек, - предложил Штирлиц.
- У вас очень доброе сердце - ответил Мюллер. - Но пусть все-таки повисят до утра.

Штирлиц шёл по улице, когда внезапно перед ним что-то упало. Штирлиц поднял глаза -- это были глаза профессора Плейшнера.

Штирлиц вышел из дома и увидел как четыре бугая ставили трактор на попа.
- Бедный пастор Шлаг, -- подумал Штирлиц

-- Штирлиц, вы еврей? -- спросил Мюллер.
-- Я русский, -- с достоинством сказал Штирлиц.
-- А я немецкий, -- усмехнулся Мюллер.

Кэт подошла к зеркалу и увидела на шее пятно.
"Засос", - подумала она, вспомнив, как вчера Штирлиц дал ей по шее за то, что она передала "СОС" открытым текстом.

Штирлицу попала в голову пуля. "Разрывная," - раскинул мозгами Штирлиц.

Штирлиц стоял на своем. Это была любимая пытка Мюллера.

Штирлиц настаивал на своем. Настойка получалась крепкой, но слегка мутноватой.

Штирлицу сказали "Пошли!!"
Штирлиц послушался, и рассказал неприличный анекдот.

Штирлиц всю ночь топил камин. На утро камин утонул.

Штирлиц стоял над картой мира. Его неудержимо рвало на родину.

Штирлиц сел в свой автомобиль и сказал шоферу: "Трогай!" Шофер потрогал, Штирлиц поехал.

Штирлиц и Кэт вышли на связь. Но в центре об этом узнали только через девять месяцев.

Штирлиц долго смотрел в одну точку. Потом в другую. "Двоеточие!" - наконец-то смекнул Штирлиц.

Письмо из центра до Штиpлица не дошло... Пришлось читать во второй раз.

Штирлиц выстрелил вслепую. Слепая упала как подкошенная. Подкошенную Штирлиц застрелил накануне.

Лампа горела, но света не давала.
"Что-то тут не так ..." - подумал Штирлиц и погасил лампу.
- Сам ты дятел, - подумал Мюллер.

- Штирлиц, как Вы относитесь к женщинам? - спросил Борман.
- Никак. Я отношусь к мужчинам. - скромно ответил Штирлиц.

Из всех машин Штирлиц предпочитал "Мерседесы", проявляя тем самым истинно немецкий патриотизм, столь полезный для конспирации.
- При этом русский разведчик очень радовался, что он - не немецкий шпион в России. А то пришлось бы ездить на "Запорожце".

- Штирлиц пришел к выводу.
- Но Вывода не было дома.

Мюллер на совещании:
— Все свободны. А вас Штирлиц я попрошу остаться.
— Ну попросите.
— Ну Штирлиц,..... ну останьтесь,.... ну пожалуйста...

Штирлиц увидел автобус с рожками.
- Троллейбус, - подумал Штирлиц.
- Сам ты, троллейбус! - обиделся автобус с рожками.

Мюллер:
- Штирлиц, вы почему не закусываете? Вы что, русский?
- Мы, немцы, народ скупой, - выкрутился Штирлиц.

Идет заседание в ставке Гитлера. Вдруг в кабинет входит Штирлиц с подносом апельсинов, ставит поднос на стол, подбирает комбинацию к сейфу, читает и фотографирует все документы, кладет их обратно, закрывает сейф и спокойно уходит. После минуты оцепенения Гитлер приходит в себя и кричит:
- Кто это такой?!
- Да это русский шпион Исаев - отвечает Мюллер
- Почему вы его не арестовали и не расстреляли?!!!
- Мы уж пытались, все равно выкрутится, скажет что апельсины приносил.

Штирлиц шёл в тумане и еле еле разбирал дорогу.
- На утро Мюллеру доложили, что 6 км дороги разобрано.


Штирлиц вкалывал в своем кабинете с утра до ночи. Однажды его застукал за этим делом Мюллер:
- Я смотрю, у вас дури на всех хватит!
С тех пор стал вкалывать весь отдел.

Из подвала Кэт увидела, что Штирлиц вышел на дорогу и начал стрелять.
- И мне одну стрельни!, - крикнула она.

Штирлиц шел по лесу. Увидел человека в фуфайке и на лыжах.
- Фуфлыжник, - подумал Штирлиц.

- Штирлиц вышел из кабака. Вдруг кто-то сильно ударил его в затылок. Обернувшись, Штирлиц увидел, что это был асфальт.

Штирлиц шел по коридору РСХА. Чеканным шагом он подошел к бюсту Гитлера и метко плюнул ему в глаз. Постояв совсем немного он вытянулся по стойке смирно и вскинув руку сказал:
- Hael Gitler!
- Конспирация, однако, - подумал Штирлиц, и довольный собой пошел дальше.

Проснувшись, Штирлиц вспомнил, что вчера на приеме у Мюллера он наговорил лишнего. Решив выяснить все разом, он вошел в кабинет и спросил:
- Мюллер, Вы догадались, что я - русский агент?
- Нет - признался Мюллер.
- Ну, слава богу - сказал Штирлиц и со спокойной душой пошел домой.
"""

# %%
train_path = 'train_dataset.txt'
with open(train_path, "wb") as f:
  f.write(text.encode('utf-8'))

train_dataset = TextDataset( tokenizer=tokenizer,file_path=train_path,block_size=64, 
                            overwrite_cache=True)

data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/data/datasets/language_modeling.py:53: FutureWarning: This dataset will be removed from the library soon, preprocessing should be handled with the 🤗 Datasets library. You can have a look at this example script for pointers: https://github.com/huggingface/transformers/blob/main/examples/pytorch/language-modeling/run_mlm.py
#   warnings.warn(

# %%
# !pip uninstall -y transformers accelerate
# !pip install transformers accelerate
# Out:
# Found existing installation: transformers 4.29.2
# Uninstalling transformers-4.29.2:
#   Successfully uninstalled transformers-4.29.2
# Found existing installation: accelerate 0.20.1
# Uninstalling accelerate-0.20.1:
#   Successfully uninstalled accelerate-0.20.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached transformers-4.29.2-py3-none-any.whl (7.1 MB)
# ...
#   Using cached accelerate-0.20.1-py3-none-any.whl (227 kB)
# ...

# %%
training_args = TrainingArguments( 
    output_dir= "./finetuned",
    overwrite_output_dir=True,
    num_train_epochs=100, 
    per_device_train_batch_size=32, 
    per_device_eval_batch_size=32,  
    gradient_accumulation_steps=16, 
    )


trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=train_dataset,
    optimizers = (torch.optim.AdamW(model.parameters(),lr=1e-5),None) # Optimizer and lr scheduler
)

# %%
trainer.train()
# Out:
# {'train_runtime': 101.2989, 'train_samples_per_second': 64.167, 'train_steps_per_second': 0.987, 'train_loss': 0.4201372528076172, 'epoch': 89.0}
# TrainOutput(global_step=100, training_loss=0.4201372528076172, metrics={'train_runtime': 101.2989, 'train_samples_per_second': 64.167, 'train_steps_per_second': 0.987, 'train_loss': 0.4201372528076172, 'epoch': 89.0})

# %%
text = "Дождь идет "
input_ids = tokenizer.encode(text, return_tensors="pt").to(DEVICE)
model.eval()
with torch.no_grad():
    out = model.generate(input_ids, 
                        do_sample=True,
                        num_beams=5, top_k=50,
                        max_length=300,
                        repetition_penalty=3.5
                        )

generated_text = list(map(tokenizer.decode, out))[0]
print()
print(generated_text)
# Out:
# Дождь идет
# Штирлиц шел по Берлину. Штирлиц вышел на улицу и увидел, как из-за угла дома выбегает разъяренный Гитлер. Обернувшись, Штирлиц увидел, что это вовсе не тот человек, которого он видел вчера.
#
# Штирлиц шел по Берлину и услышал за спиной шаги Гитлера. Обернувшись, он увидел, что это совсем не тот человек, которого он видел вчера.
#
# Штирлиц шел по Берлину и слышал за спиной шаги Гитлера. Обернувшись, Штирлиц увидел, что это совсем не тот человек, которого он видел вчера.
#
# Штирлиц шел по Берлину и слышал за спиной шаги Гитлера. Обернувшись, Штирлиц увидел, что это совсем не тот человек, которого он видел вчера.
#
# Штирлиц шел по Берлину и слышал за спиной шаги Гитлера. Обернувшись, Штирлиц увидел, что это совсем не тот человек, которого он видел вчера.
#
# Штирлиц шел по Берлину и слышал за спиной шаги Гитлера. Обернувшись, Штирлиц увидел, что это совсем не тот человек, которого он видел вчера.
#
# ...

# %% [markdown]
# К дождю совергшенно никакого отношения, повторения (жутковато), но абсурдно в стиле анекдотов про Штирлица.

# %%
# увеличим top_k и repetition_penalty

text = "Идёт заседание"
input_ids = tokenizer.encode(text, return_tensors="pt").to(DEVICE)
model.eval()
with torch.no_grad():
    out = model.generate(input_ids, 
                        do_sample=True,
                        num_beams=5, 
                        top_k=70,
                        max_length=150,
                        repetition_penalty=5.3
                        )

generated_text = list(map(tokenizer.decode, out))[0]
print()
print(generated_text)
# Out:
# Идёт заседание Политбюро ЦК ВКП(б). Сталин спрашивает у Мюллера:
# - Вы читали Штирлица?
# - Нет, - отвечает Мюллер.
# - А я читал его "Майн кампф".
#
# Штирлиц сидел в кабинете Гитлера и пил кофе. Вдруг к нему подходит Гитлер и говорит:
# - Геббельс, вы знаете, что такое немецкий язык?
# - Да, - ответил Штирлиц.
# - Тогда прочитайте мне ещё одну книгу по немецкому языку...
#
# Штирлиц вышел из кабинета и увидел на стене портрет Сталина. На портрете была изображена бородатая голова с квадратным подбородком. Под портретом было написано: "Товарищ Сталин!".
#
# Штир

# %% [markdown]
# Довольно правдоподобно и абсурдно.

# %%
# увеличим число пучков, запретим повторять биграммы

text = "Проснувшись, Штирлиц вспомнил"
input_ids = tokenizer.encode(text, return_tensors="pt").to(DEVICE)
model.eval()
with torch.no_grad():
    out = model.generate(input_ids, 
                        do_sample=True,
                        num_beams=10, 
                        top_k=70,
                        max_length=200,
                        no_repeat_ngram_size=2
                        )

generated_text = list(map(tokenizer.decode, out))[0]
print()
print(generated_text)
# Out:
# Проснувшись, Штирлиц вспомнил, что его разбудил телефонный звонок.
# - Алло, - сказал он. - Это Мюллер?
# Мюллер ответил не сразу, но через некоторое время
# Штирлицу пришла в голову гениальная мысль: "Если я сейчас не усну, меня арестуют".
#
# В кабинете Гитлера зазвонил телефон. Гитлер снял трубку и услышал голос Мюллера:
# &mdash;&nbsp;Гитлер, вы что, спятили? Я вас не шучу. Я вам сейчас расскажу, как я вас обманул, и вы узнаете, кто я на самом деле. А сейчас я хочу задать вам один очень важный вопрос. Вы когда-нибудь слышали, чтобы кто-то говорил по-немецки? Нет? Тогда вам это не удастся, потому что вы не знаете ни одного слова на этом языке. Но если вы все-таки вспомните, то я вам очень признателен за это. У меня есть для вас секрет.

# %% [markdown]
# Первый текст - не анекдот, но очень точно описывает какой-нибудь ночной кошмар.
# Второй - изящная гипотеза о том, что немецкого языка не существует, вполне похожая на анекдот. (Как преподователь немецкого - не одобряю).

# %%
#запретим повторять триграммы
text = "Мюллер вызывает Штирлица и говорит"
input_ids = tokenizer.encode(text, return_tensors="pt").to(DEVICE)
model.eval()
with torch.no_grad():
    out = model.generate(input_ids, 
                        do_sample=True,
                        num_beams=10,
                        top_k=70,
                        max_length=200,
                        no_repeat_ngram_size=3
                        )

generated_text = list(map(tokenizer.decode, out))[0]
print()
print(generated_text)
# Out:
# Мюллер вызывает Штирлица и говорит:
# - Штирлиц, вы русский?
# - Нет, - отвечает Мюллер.
# - А я немецкий.
#
# Штирлиц и Мюллер идут по лесу. Вдруг из-за куста выскакивает собака и начинает лаять. Штирлицу кажется, что это немецкая овчарка. Он подходит к кусту, нюхает его и убегает.
# Через некоторое время Мюллер видит, что за кустом кто-то стоит. Обернувшись, он видит человека, который смотрит на него с ненавистью. "Это я, - думает Мюллер, - это я, это я".
# - Кто это? - спросил Мюллер и посмотрел на человека.
# Тот посмотрел на него и сказал: "Это Мюллер".
#
# Однажды Мюллер пришел в гости к Мюллеру и рассказал ему, что у него есть секретная папка, в которой хранятся секретные документы. Мюллер раскрыл папку и увидел

# %% [markdown]
# Минутка самоуничижения от Мюллера.

# %%
# уберём пучки, ещё немного увеличим top k, уменьшим температуру

text = "Штирлиц вышел"
input_ids = tokenizer.encode(text, return_tensors="pt").to(DEVICE)
model.eval()
with torch.no_grad():
    out = model.generate(input_ids, 
                        do_sample=True,
                        top_k=80,
                        max_length=150,
                        temperature = 0.3,
                        no_repeat_ngram_size=3
                        )

generated_text = list(map(tokenizer.decode, out))[0]
print()
print(generated_text)
# Out:
# Штирлиц вышел из-за стола и увидел Штирлица.
# - Штирлиц, вы не могли бы мне помочь?
# - А что?
#
# Штирлицу было лет сорок.
# Штерлиц был очень красивый.
#
# - Я не штирлиц. Я - Штирлиец.
# Вдруг из-под стола выскользнула рука и ударила Штирлия по лбу.
# В это время из- под стола вышел Штирлин и сказал:
# - Вы не Штирлик. Вы - Штилер.
# И тут из- за стола вышел Мюллер. Он сказал: "Я не Штилин. Вы не Мюллер".
#
# В кабинете Гитлера сидел Штирл и разговаривал с

# %% [markdown]
# Без пучков получается не очень. Но тексты осмысленные. Особенное удивление вызывают изменения в имени Штирлица.

# %%
text = "Мюллер вызывает Штирлица и говорит"
input_ids = tokenizer.encode(text, return_tensors="pt").to(DEVICE)
model.eval()
with torch.no_grad():
    out = model.generate(input_ids, 
                        do_sample=True,
                        num_beams=5,
                        top_k=70,
                        max_length=150,
                        no_repeat_ngram_size=3
                        )

generated_text = list(map(tokenizer.decode, out))[0]
print()
print(generated_text)
# Out:
# Мюллер вызывает Штирлица и говорит:
# - Штирлиц, вы знаете, у меня к вам предложение.
# - Какое?
# - Я хочу, чтобы вы взяли меня в жены.
#
# Штирлиц шел по лесу и вдруг увидел, что кто-то идет по его следу. Обернувшись, он увидел на дереве человека. Подойдя поближе, он узнал в этом человеке Мюллера. "Это Мюллер, - подумал Штирлицу Мюллер. - А может быть, это и есть тот самый Мюллер?"
#
# В берлинском кафе к столику подошла официантка и спросила: "Вы русский?"
# - Нет, - ответил посетитель. - Я еврей.
# "Ну, - подумала официантка, -

# %% [markdown]
# Я теперь догадываюсь, как генерируются шутки из великого канала в телеграме "Мои любимые юморески" :))
#
#
# Поскольку юмор в анекдотах про Штирлица абсурдный, воспроизвести его довольно сложно. Но тексты в целом получаются неплохие и осмысленные. Под конец выполнения задания у меня окончательно сломалось чувство юмора, и полученные тексты стали казаться смешными.

# %% [markdown]
# ### Задание  2 (2 балла)
#
# Ответьте на следующие вопросы:
#
# 1) В каких статья были представлены GPT-1, GPT-2, GPT-3?
#
# 2) Как собирался обучающий корпус для GPT-3? Каким образом создатели старались обеспечить высокое качество текстов в обучающей выборке?

# %% [markdown]
# ### **1**

# %% [markdown]
# - GPT-1: Improving Language Understanding by Generative Pre-Training (2018) (https://cdn.openai.com/research-covers/language-unsupervised/language_understanding_paper.pdf)
# - GPT-2: Language Models are Unsupervised Multitask Learners (2019) (https://cdn.openai.com/better-language-models/language_models_are_unsupervised_multitask_learners.pdf)
# - GPT-3: Language Models are Few-Shot Learners (2020) (https://arxiv.org/pdf/2005.14165.pdf)

# %% [markdown]
# ### **2**

# %% [markdown]
# Основная база данных, использованная для обучения GPT-3 - Common Crawl.
#
# Она создавалась с 2008 года с помощью веб-краулинга и теперь содержит почти триллион токенов. Качество модели повысили с помощью улучшения наборов данных. Были взяты англоязычная Википедия и книжные корпусы, и Common Crawl была отфильтрована, основываясь на сходстве с ними. Эти данные также добавили в обучающую выборку.
#
# Чтобы избежать избыточности и повторов, провели дедупликацию документов. К тому же, были взяты данные только за период с 2016 по 2019 год (410 миллиардов токенов).
